# %%
from mvp_module import *

# %%
model = mvp_model('model', 'scaler')

# %%
model.load_and_clean('new_data.csv')

# %%
df = model.predicted_output()

# %%
df.sort_values('Probability', ascending = False)
# Out:
#                      Player  Age  Num_Stars  USG%  TRB%  AST%    TS%  \
# 0              James Harden   30          2  37.5   8.2  35.9  0.645
# 1     Giannis Antetokounmpo   25          2  37.6  20.4  32.3  0.617
# 2               Luka Dončić   20          1  36.9  15.3  48.1  0.609
# 12             LeBron James   35          2  31.3  12.3  51.5  0.563
# 14        Russell Westbrook   31          2  32.9  11.7  32.9  0.503
# 8             Kawhi Leonard   28          4  33.3  12.3  27.2  0.559
# 17              Paul George   29          4  31.0  10.0  19.7  0.586
# 16              Joel Embiid   25          2  31.7  22.3  36.8  0.593
# 3                Trae Young   21          1  34.8   6.7  43.0  0.589
# 4              Bradley Beal   26          1  32.2   7.2  29.0  0.554
# 5             Anthony Davis   26          2  30.2  14.8  14.8  0.609
# 18        Spencer Dinwiddie   26          1  32.0   5.0  35.5  0.550
# 6            Damian Lillard   29          2  29.0   5.8  32.7  0.603
# ...
